# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from os import listdir

# %%
def read_all():
    df = pd.concat([pd.read_json(f'data/{f}') for f in listdir('data') if f.endswith('.json')]).reset_index(drop=True)
    return df

def process_data(df):
    items = df['CVE_Items']
    
    def _clean(item):
        
        values = {
            'cve_id': item['cve']['CVE_data_meta']['ID']
        }
        
        # Add metrics
        for version in ['2', '3']:
            if f'baseMetricV{version}' in item['impact']:
                v = item['impact'][f'baseMetricV{version}'].copy()
                cvss = v.pop(f'cvssV{version}')
                values.update({f'V{version}_{key}': value for key, value in v.items()})
                values.update({f'V{version}_{key}': value for key, value in cvss.items()})
        
        return pd.Series(values)
    
    return items.apply(_clean)

# %%
src_data = read_all()

# %%
df = process_data(src_data)

# %%
df.head()
# Out:
#           cve_id V2_severity  V2_exploitabilityScore  V2_impactScore  \
# 0  CVE-2011-0001      MEDIUM                    10.0             2.9
# 1  CVE-2011-0002      MEDIUM                    10.0             4.9
# 2  CVE-2011-0003      MEDIUM                     8.6             4.9
# 3  CVE-2011-0004      MEDIUM                     8.6             2.9
# 4  CVE-2011-0005      MEDIUM                     8.6             2.9
#
#   V2_obtainAllPrivilege V2_obtainUserPrivilege V2_obtainOtherPrivilege  \
# 0                 False                  False                   False
# 1                 False                  False                   False
# 2                 False                  False                   False
# 3                 False                  False                   False
# 4                 False                  False                   False
#
#   V2_userInteractionRequired V2_version             V2_vectorString  ...  \
# 0                      False        2.0  AV:N/AC:L/Au:N/C:N/I:N/A:P  ...
# 1                      False        2.0  AV:N/AC:L/Au:N/C:P/I:P/A:N  ...
# 2                       True        2.0  AV:N/AC:M/Au:N/C:P/I:P/A:N  ...
# 3                       True        2.0  AV:N/AC:M/Au:N/C:N/I:P/A:N  ...
# 4                       True        2.0  AV:N/AC:M/Au:N/C:N/I:P/A:N  ...
#
#   V3_attackVector V3_attackComplexity V3_privilegesRequired  \
# 0             NaN                 NaN                   NaN
# 1             NaN                 NaN                   NaN
# 2             NaN                 NaN                   NaN
# 3             NaN                 NaN                   NaN
# 4             NaN                 NaN                   NaN
#
#   V3_userInteraction V3_scope V3_confidentialityImpact  V3_integrityImpact  \
# 0                NaN      NaN                      NaN                 NaN
# 1                NaN      NaN                      NaN                 NaN
# 2                NaN      NaN                      NaN                 NaN
# 3                NaN      NaN                      NaN                 NaN
# 4                NaN      NaN                      NaN                 NaN
#
#   V3_availabilityImpact  V3_baseScore  V3_baseSeverity
# 0                   NaN           NaN              NaN
# 1                   NaN           NaN              NaN
# 2                   NaN           NaN              NaN
# 3                   NaN           NaN              NaN
# 4                   NaN           NaN              NaN
#
# [5 rows x 32 columns]

# %%
df.to_parquet('data/df_v1.pqt')

# %%
# Now values that are only have valid CVEs
only_valid = df[~df['V2_impactScore'].isna()].reset_index()
only_valid.to_parquet('data/df_v2.pqt')

# %%
df.shape
# Out:
# (161262, 32)

# %%
df.describe()
# Out:
#        V2_exploitabilityScore  V2_impactScore   V2_baseScore  \
# count           151637.000000   151637.000000  151637.000000
# mean                 8.134079        5.541438       5.977483
# std                  2.162143        2.622113       2.001626
# min                  1.200000        0.000000       0.000000
# 25%                  8.000000        2.900000       4.300000
# 50%                  8.600000        6.400000       5.500000
# 75%                 10.000000        6.400000       7.500000
# max                 10.000000       10.000000      10.000000
#
#        V3_exploitabilityScore  V3_impactScore  V3_baseScore
# count            78264.000000    78264.000000  78264.000000
# mean                 2.712022        4.388922      7.240122
# std                  0.944379        1.509976      1.652467
# min                  0.100000        1.400000      1.800000
# 25%                  1.800000        3.600000      6.100000
# 50%                  2.800000        3.600000      7.500000
# 75%                  3.900000        5.900000      8.800000
# max                  3.900000        6.000000     10.000000

# %% [markdown]
# ## Viewing the number of CVEs that have V2 and V3 metrics

# %%
(~df['V2_impactScore'].isna()).sum(), (~df['V3_impactScore'].isna()).sum()
# Out:
# (151637, 78264)

# %% [markdown]
# ### Explore the rows that have missing data

# %%
missing = df[df['V2_impactScore'].isna()].index

# %%
src_data.loc[missing]
# Out:
#        CVE_data_type CVE_data_format  CVE_data_version  CVE_data_numberOfCVEs  \
# 42               CVE           MITRE                 4                   4813
# 57               CVE           MITRE                 4                   4813
# 91               CVE           MITRE                 4                   4813
# 95               CVE           MITRE                 4                   4813
# 96               CVE           MITRE                 4                   4813
# ...              ...             ...               ...                    ...
# 161209           CVE           MITRE                 4                   5002
# 161210           CVE           MITRE                 4                   5002
# 161211           CVE           MITRE                 4                   5002
# 161212           CVE           MITRE                 4                   5002
# 161249           CVE           MITRE                 4                   5002
#
#        CVE_data_timestamp                                          CVE_Items
# 42      2021-04-13T08:23Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 57      2021-04-13T08:23Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 91      2021-04-13T08:23Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 95      2021-04-13T08:23Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 96      2021-04-13T08:23Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# ...                   ...                                                ...
# 161209  2021-04-13T08:27Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 161210  2021-04-13T08:27Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 161211  2021-04-13T08:27Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 161212  2021-04-13T08:27Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 161249  2021-04-13T08:27Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
#
# [9625 rows x 6 columns]

# %%
src_data.loc[missing]['CVE_Items'].apply(lambda x: x['cve']['description']['description_data'])
# Out:
# 42        [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 57        [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 91        [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 95        [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 96        [{'lang': 'en', 'value': '** REJECT **  DO NOT...
#                                 ...
# 161209    [{'lang': 'en', 'value': '** REJECT ** DO NOT ...
# 161210    [{'lang': 'en', 'value': '** REJECT ** DO NOT ...
# 161211    [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 161212    [{'lang': 'en', 'value': '** REJECT **  DO NOT...
# 161249    [{'lang': 'en', 'value': '** REJECT ** DO NOT ...
# Name: CVE_Items, Length: 9625, dtype: object

# %% [markdown]
# ### Get the first 12 characters of the value of those that were not correct

# %%
length_of_one = (src_data.loc[missing]['CVE_Items'].apply(lambda x: len(x['cve']['description']['description_data'])) == 1)
src_data.loc[missing][length_of_one]['CVE_Items'].apply(lambda x: x['cve']['description']['description_data'][0]['value'][:12]).value_counts(normalize=True)
# Out:
# ** REJECT **    0.958785
# Remote Proce    0.002817
# Multiple vul    0.001565
# A vulnerabil    0.001356
# An improper     0.001148
#                   ...
# A clear text    0.000104
# ZEROF Web Se    0.000104
# Improper han    0.000104
# Some ZTE pro    0.000104
# Windows Reso    0.000104
# Name: CVE_Items, Length: 226, dtype: float64

# %% [markdown]
# ### Since a large number of those were rejected, we skip them from the rest of the analysis

# %%
impact_vars = ['V2_confidentialityImpact', 'V2_integrityImpact', 'V2_availabilityImpact', 'V3_confidentialityImpact', 'V3_integrityImpact', 'V3_availabilityImpact']
df[impact_vars]
# Out:
#        V2_confidentialityImpact V2_integrityImpact V2_availabilityImpact  \
# 0                          NONE               NONE               PARTIAL
# 1                       PARTIAL            PARTIAL                  NONE
# 2                       PARTIAL            PARTIAL                  NONE
# 3                          NONE            PARTIAL                  NONE
# 4                          NONE            PARTIAL                  NONE
# ...                         ...                ...                   ...
# 161257                     NONE               NONE               PARTIAL
# 161258                 COMPLETE           COMPLETE              COMPLETE
# 161259                 COMPLETE           COMPLETE              COMPLETE
# 161260                     NONE            PARTIAL                  NONE
# 161261                     NONE            PARTIAL                  NONE
#
#        V3_confidentialityImpact V3_integrityImpact V3_availabilityImpact
# 0                           NaN                NaN                   NaN
# 1                           NaN                NaN                   NaN
# 2                           NaN                NaN                   NaN
# 3                           NaN                NaN                   NaN
# 4                           NaN                NaN                   NaN
# ...                         ...                ...                   ...
# 161257                     NONE               NONE                  HIGH
# 161258                     HIGH               HIGH                  HIGH
# 161259                     HIGH               HIGH                  HIGH
# 161260                      LOW                LOW                  NONE
# 161261                      LOW                LOW                  NONE
#
# [161262 rows x 6 columns]

# %%
impact = df[['cve_id'] + impact_vars]

# %% [markdown]
# ## Check if impact values can be mapped from V2 to V3
# First we get the rows that are valid for both v2 and v3

# %%
valid = impact.dropna()
valid.shape
# Out:
# (78264, 7)

# %% [markdown]
# ### confidentiality
# If they can be mapped, then no value of V2 should appear with different values of V3 and viceversa

# %%
valid.groupby(['V2_confidentialityImpact', 'V3_confidentialityImpact']).size().rename('number_of_cves').to_frame()
# Out:
#                                                    number_of_cves
# V2_confidentialityImpact V3_confidentialityImpact
# COMPLETE                 HIGH                               13055
#                          LOW                                    7
#                          NONE                                   4
# NONE                     HIGH                                 135
#                          LOW                                 8994
#                          NONE                               16953
# PARTIAL                  HIGH                               32956
#                          LOW                                 6102
#                          NONE                                  58

# %% [markdown]
# We see that the mapping is not direct, although COMPLETE V2 confidentiality impacts tend to have a HIGH V3 value

# %% [markdown]
# ### integrity
# If they can be mapped, then no value of V2 should appear with different values of V3 and viceversa

# %%
valid.groupby(['V2_integrityImpact', 'V3_integrityImpact']).size().rename('number_of_cves').to_frame()
# Out:
#                                        number_of_cves
# V2_integrityImpact V3_integrityImpact
# COMPLETE           HIGH                         12731
#                    LOW                              1
#                    NONE                             4
# NONE               HIGH                          1177
#                    LOW                             51
#                    NONE                         24368
# PARTIAL            HIGH                         26197
#                    LOW                          13707
#                    NONE                            28

# %% [markdown]
# The same occurs for the integrity values

# %% [markdown]
# ### availability
# If they can be mapped, then no value of V2 should appear with different values of V3 and viceversa

# %%
valid.groupby(['V2_availabilityImpact', 'V3_availabilityImpact']).size().rename('number_of_cves').to_frame()
# Out:
#                                              number_of_cves
# V2_availabilityImpact V3_availabilityImpact
# COMPLETE              HIGH                            15352
#                       LOW                                 4
#                       NONE                               54
# NONE                  HIGH                             1237
#                       LOW                                63
#                       NONE                            29815
# PARTIAL               HIGH                            29206
#                       LOW                              1987
#                       NONE                              546

# %% [markdown]
# The same occurs for the V2 COMPLETE values, although for availability, in V3 most of them, if defined, go to HIGH
